# %%
import tensorflow as tf
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from keras import models
from keras import layers
from tensorflow.keras import datasets, layers, models
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.preprocessing import LabelEncoder

# %%
'''
Go to Kaggle.com. Find a text classification data set that interests you. Divide into train/test.
Create a graph showing the distribution of the target classes. Describe the data set and what the
model should be able to predict.
'''
# Load the df & remove redundant column
df = pd.read_csv('tweet_emotions.csv')
df = df.drop('tweet_id', axis=1)

# Test/Train Split
train_data, test_data, train_labels, test_labels = train_test_split(df['content'], df['sentiment'], test_size=0.5, random_state=1337)

print('Size of training and test data:', train_labels.shape, test_labels.shape)

# Graph the distribution of the target classes (Sentiment)
fig, ax = plt.subplots()
df['sentiment'].value_counts().plot(kind='bar', ax=ax)

ax.set_title('Distribution of Target Classes')
ax.set_xlabel('Sentiment')
ax.set_ylabel('Count')

plt.show()
# Out:
# Size of training and test data: (20000,) (20000,)

# %%
'''
Create a sequential model and evaluate on the test data
'''
# Vectorize/Encode the data
vectorizer = TfidfVectorizer(stop_words='english')
label_encoder = LabelEncoder()

x_train = vectorizer.fit_transform(train_data).toarray()
x_test = vectorizer.transform(test_data).toarray()

y_train = label_encoder.fit_transform(train_labels)
y_test = label_encoder.transform(test_labels)

# Adjust the input shape to match the length of the vectorized features
input_shape = x_train.shape[1]

# Build the model
model = models.Sequential()
model.add(layers.Dense(16, activation='relu', input_shape=(input_shape,)))
model.add(layers.Dense(16, activation='relu'))
model.add(layers.Dense(1, activation='sigmoid'))

# Compile the model
model.compile(optimizer='rmsprop',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# Create a validation set
x_val = x_train[:10000]
partial_x_train = x_train[10000:]

y_val = y_train[:10000]
partial_y_train = y_train[10000:]

# Train the model
history = model.fit(partial_x_train,
                    partial_y_train,
                    epochs=20,
                    batch_size=512,
                    validation_data=(x_val, y_val))
# Out:
# Epoch 1/20
# 20/20 [==============================] - 2s 79ms/step - loss: -0.4773 - accuracy: 0.0040 - val_loss: -1.7591 - val_accuracy: 0.0055
# Epoch 2/20
# 20/20 [==============================] - 1s 36ms/step - loss: -3.0561 - accuracy: 0.0040 - val_loss: -4.5257 - val_accuracy: 0.0055
# Epoch 3/20
# 20/20 [==============================] - 1s 33ms/step - loss: -6.2366 - accuracy: 0.0040 - val_loss: -7.9758 - val_accuracy: 0.0055
# Epoch 4/20
# 20/20 [==============================] - 1s 32ms/step - loss: -10.1727 - accuracy: 0.0040 - val_loss: -12.1792 - val_accuracy: 0.0055
# Epoch 5/20
# 20/20 [==============================] - 1s 31ms/step - loss: -14.9357 - accuracy: 0.0040 - val_loss: -17.2070 - val_accuracy: 0.0055
# Epoch 6/20
# 20/20 [==============================] - 1s 31ms/step - loss: -20.6009 - accuracy: 0.0040 - val_loss: -23.1250 - val_accuracy: 0.0055
# Epoch 7/20
# 20/20 [==============================] - 1s 32ms/step - loss: -27.2203 - accuracy: 0.0040 - val_loss: -29.9795 - val_accuracy: 0.0055
# Epoch 8/20
# 20/20 [==============================] - 1s 30ms/step - loss: -34.8853 - accuracy: 0.0040 - val_loss: -37.8921 - val_accuracy: 0.0055
# Epoch 9/20
# 20/20 [==============================] - 1s 29ms/step - loss: -43.6727 - accuracy: 0.0040 - val_loss: -46.8682 - val_accuracy: 0.0055
# Epoch 10/20
# 20/20 [==============================] - 1s 29ms/step - loss: -53.6157 - accuracy: 0.0040 - val_loss: -57.0019 - val_accuracy: 0.0055
# Epoch 11/20
# 20/20 [==============================] - 1s 30ms/step - loss: -64.8329 - accuracy: 0.0040 - val_loss: -68.3587 - val_accuracy: 0.0055
# Epoch 12/20
# 20/20 [==============================] - 1s 30ms/step - loss: -77.3564 - accuracy: 0.0040 - val_loss: -81.0095 - val_accuracy: 0.0055
# Epoch 13/20
# 20/20 [==============================] - 1s 28ms/step - loss: -91.2437 - accuracy: 0.0040 - val_loss: -94.9674 - val_accuracy: 0.0055
# Epoch 14/20
# 20/20 [==============================] - 1s 30ms/step - loss: -106.5902 - accuracy: 0.0040 - val_loss: -110.3615 - val_accuracy: 0.0055
# Epoch 15/20
# 20/20 [==============================] - 1s 29ms/step - loss: -123.4290 - accuracy: 0.0040 - val_loss: -127.1614 - val_accuracy: 0.0055
# Epoch 16/20
# 20/20 [==============================] - 1s 29ms/step - loss: -141.8303 - accuracy: 0.0040 - val_loss: -145.5500 - val_accuracy: 0.0055
# Epoch 17/20
# 20/20 [==============================] - 1s 29ms/step - loss: -161.9077 - accuracy: 0.0040 - val_loss: -165.5488 - val_accuracy: 0.0055
# Epoch 18/20
# 20/20 [==============================] - 1s 30ms/step - loss: -183.6688 - accuracy: 0.0040 - val_loss: -187.1081 - val_accuracy: 0.0055
# Epoch 19/20
# 20/20 [==============================] - 1s 30ms/step - loss: -207.2061 - accuracy: 0.0040 - val_loss: -210.4476 - val_accuracy: 0.0055
# Epoch 20/20
# 20/20 [==============================] - 0s 25ms/step - loss: -232.5979 - accuracy: 0.0040 - val_loss: -235.6228 - val_accuracy: 0.0055

# %%
'''
Try a different architecture like RNN, CNN, etc and evaluate on the test data
'''
# Out:
# '\nTry a different architecture like RNN, CNN, etc and evaluate on the test data\n'

# %%
'''
Try different embedding approaches and evaluate on the test data
'''
# Out:
# '\nTry different embedding approaches and evaluate on the test data\n'

# %%
'''
Write up your analysis of the performance of various approaches
'''
# Out:
# '\nWrite up your analysis of the performance of various approaches\n'
